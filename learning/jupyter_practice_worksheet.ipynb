# %% [markdown]
# # Jupyter Notebook Practice Worksheet
# Welcome! Work through these exercises to build confidence using Jupyter Notebook.

# %% [markdown]
# ## 1. Running Code Cells
# Run the code below. Then modify it to print your name.

# %%
print('Hello, Jupyter!')
# Out:
# Hello, Jupyter!

# %% [markdown]
# ## 2. Variables and Basic Math
# Create variables and perform arithmetic.

# %%
a = 10
b = 5
a + b
# Out:
# 15

# %% [markdown]
# ## 3. Writing Markdown
# Convert this cell to **Markdown** and write a short paragraph about what you want to learn in Python.

# %% [markdown]
# ## 4. Creating Lists and Loops
# Create a list of three goals for learning Python, then loop through it and print each one.

# %%
goals = ['Learn data analysis', 'Understand Python basics', 'Build a project']
for g in goals:
    print(g)
# Out:
# Learn data analysis
# Understand Python basics
# Build a project

# %% [markdown]
# ## 5. Functions
# Write a function that takes a number and returns its square. Test it with 3 different values.

# %%
def square(x):
    return x * x

# Test
a = square(3)
b = square(5)
c = square(12)
a, b, c
# Out:
# (9, 25, 144)

# %% [markdown]
# ## 6. Simple Plot
# Run this to create a basic plot. Try changing the values.

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]
plt.plot(x, y)
plt.title('Example Plot')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ## 7. Practice Task: Mini-Project
# Create a notebook section where you:
# 1. Make a list of numbers 1–20.
# 2. Loop through and collect only even numbers.
# 3. Plot the even numbers.
# 4. Write a Markdown summary of what you learned.
