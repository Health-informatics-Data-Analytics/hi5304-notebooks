# %% [markdown]
# # HI 5304 – Week 1
# ## Introduction to Health Informatics Data Analytics
#
# Welcome to HI 5304. This notebook is designed to help you:
#
# - Become familiar with GitHub and Jupyter Notebooks
# - Run Python code in a reproducible environment
# - Understand how analytics workflows will be used in this course
#
# This notebook is **for learning and practice**.
# Assignments will be submitted through **GitHub Classroom**.

# %% [markdown]
# ### Learning Objectives
#
# By the end of this activity, you should be able to:
#
# 1. Open and run a Jupyter Notebook
# 2. Execute basic Python code
# 3. Interpret simple outputs
# 4. Explain how GitHub is used in this course

# %%
# This is your first Python cell
print("Welcome to HI 5304: Health Informatics Data Analytics!")
# Out:
# Welcome to HI 5304: Health Informatics Data Analytics!

# %%
import sys
sys.version
# Out:
# '3.12.1 (main, Nov 27 2025, 10:47:52) [GCC 13.3.0]'
